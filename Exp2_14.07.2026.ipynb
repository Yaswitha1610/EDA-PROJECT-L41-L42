# %%
import pandas as pd
df=pd.read_csv("/content/airline_passenger_satisfaction.csv")

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
df.tail()
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 129875              447                2            3.0
# 129876              308                0            0.0
# 129877              337                6           14.0
# 129878              337               31           22.0
# 129879              337                0            0.0
#
#         Departure and Arrival Time Convenience  ...  On-board Service  \
# 129875                                       4  ...                 5
# ...

# %%
df.shape
# Out:
# (129880, 24)

# %%
df.columns
# Out:
# Index(['ID', 'Gender', 'Age', 'Customer Type', 'Type of Travel', 'Class',
#        'Flight Distance', 'Departure Delay', 'Arrival Delay',
#        'Departure and Arrival Time Convenience', 'Ease of Online Booking',
#        'Check-in Service', 'Online Boarding', 'Gate Location',
#        'On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness',
#        'Food and Drink', 'In-flight Service', 'In-flight Wifi Service',
#        'In-flight Entertainment', 'Baggage Handling', 'Satisfaction'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129880.000000
# mean       15.091129                                3.057599
# std        38.465650                                1.526741
# min         0.000000                                0.000000
# ...

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female    65899
# Male      63981
# Name: count, dtype: int64

# %%
df["Customer Type"].value_counts()
# Out:
# Customer Type
# Returning     106100
# First-time     23780
# Name: count, dtype: int64

# %%
df["Type of Travel"].value_counts()
# Out:
# Type of Travel
# Business    89693
# Personal    40187
# Name: count, dtype: int64

# %%
df["Class"].value_counts()
# Out:
# Class
# Business        62160
# Economy         58309
# Economy Plus     9411
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# ...

# %%
df.notnull().sum()
# Out:
# ID                                        129880
# Gender                                    129880
# Age                                       129880
# Customer Type                             129880
# Type of Travel                            129880
# Class                                     129880
# Flight Distance                           129880
# Departure Delay                           129880
# Arrival Delay                             129487
# Departure and Arrival Time Convenience    129880
# Ease of Online Booking                    129880
# Check-in Service                          129880
# Online Boarding                           129880
# Gate Location                             129880
# On-board Service                          129880
# Seat Comfort                              129880
# Leg Room Service                          129880
# Cleanliness                               129880
# Food and Drink                            129880
# ...

# %%
df["Age After 5 Years"]=df["Age"]+5

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
df[["Gender", "Age", "Class", "Age After 5 Years"]].head()
# Out:
#    Gender  Age     Class  Age After 5 Years
# 0    Male   48  Business                 53
# 1  Female   35  Business                 40
# 2    Male   41  Business                 46
# 3    Male   50  Business                 55
# 4  Female   49  Business                 54

# %%
df1=df.iloc[:100]
df2=df.iloc[100:200]

# %%
vertical_concat=pd.concat([df1,df2], ignore_index = True)
vertical_concat.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
horizontal_concat=pd.concat([df1.reset_index(drop=True), df2.reset_index(drop=True)], axis=1)
horizontal_concat.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
vertical_concat.shape
# Out:
# (200, 25)

# %%
horizontal_concat.shape
# Out:
# (100, 50)

# %%
left=df[["ID", "Gender"]]
right=df[["ID", "Age"]]
merged=pd.merge(left,right,on="ID")
merged.head()
# Out:
#    ID  Gender  Age
# 0   1    Male   48
# 1   2  Female   35
# 2   3    Male   41
# 3   4    Male   50
# 4   5  Female   49

# %%
gender_series=df["Gender"]
gender_series.head()
# Out:
# 0      Male
# 1    Female
# 2      Male
# 3      Male
# 4    Female
# Name: Gender, dtype: object

# %%
s1=df["Gender"].head()
s2=df["Age"].head()
pd.concat([s1,s2], keys=["Gender","Age"])
# Out:
# Gender  0      Male
#         1    Female
#         2      Male
#         3      Male
#         4    Female
# Age     0        48
#         1        35
#         2        41
#         3        50
#         4        49
# dtype: object

# %%
multi_df=df.set_index(["Gender","Class"])
multi_df.head()
# Out:
#                  ID  Age Customer Type Type of Travel  Flight Distance  \
# Gender Class
# Male   Business   1   48    First-time       Business              821
# Female Business   2   35     Returning       Business              821
# Male   Business   3   41     Returning       Business              853
#        Business   4   50     Returning       Business             1905
# Female Business   5   49     Returning       Business             3470
#
#                  Departure Delay  Arrival Delay  \
# Gender Class
# Male   Business                2            5.0
# Female Business               26           39.0
# Male   Business                0            0.0
#        Business                0            0.0
# Female Business                0            1.0
#
#                  Departure and Arrival Time Convenience  \
# Gender Class
# Male   Business                                       3
# Female Business                                       2
# ...

# %%
df.sort_values(by="Age")
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 129783  129784  Female    7     Returning       Personal       Economy
# 123        124  Female    7     Returning       Personal       Economy
# 124952  124953    Male    7     Returning       Personal  Economy Plus
# 113695  113696  Female    7     Returning       Personal       Economy
# 123183  123184    Male    7     Returning       Personal       Economy
# ...        ...     ...  ...           ...            ...           ...
# 92779    92780  Female   85     Returning       Business      Business
# 44736    44737    Male   85     Returning       Business  Economy Plus
# 70254    70255  Female   85     Returning       Business      Business
# 56962    56963    Male   85    First-time       Business       Economy
# 37232    37233    Male   85     Returning       Business      Business
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 129783              337                0            0.0
# ...

# %%
df.sort_values(by="Flight Distance", ascending=False)
# Out:
#           ID  Gender  Age Customer Type Type of Travel         Class  \
# 31815  31816  Female   45     Returning       Personal       Economy
# 31812  31813  Female   37     Returning       Business      Business
# 31816  31817    Male   38     Returning       Business  Economy Plus
# 31814  31815  Female   49     Returning       Business      Business
# 31811  31812    Male   42     Returning       Business      Business
# ...      ...     ...  ...           ...            ...           ...
# 30211  30212  Female   27     Returning       Personal  Economy Plus
# 29991  29992  Female   26    First-time       Business       Economy
# 30183  30184    Male   43     Returning       Business  Economy Plus
# 29862  29863  Female   53     Returning       Business       Economy
# 29823  29824  Female   23    First-time       Business       Economy
#
#        Flight Distance  Departure Delay  Arrival Delay  \
# 31815             4983                2            0.0
# ...

# %%
df[df["Age"]>40]
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# 5            6    Male   43     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129872  129873  Female   44     Returning       Personal  Economy Plus
# 129874  129875  Female   55     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...

# %%
df[df["Gender"]=="Female"]
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 1            2  Female   35     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# 7            8  Female   60     Returning       Business      Business
# 9           10  Female   38     Returning       Business      Business
# 10          11  Female   28    First-time       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129871  129872  Female   32     Returning       Business  Economy Plus
# 129872  129873  Female   44     Returning       Personal  Economy Plus
# 129873  129874  Female   28     Returning       Personal  Economy Plus
# 129874  129875  Female   55     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 1                   821               26           39.0
# ...

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["Class"].unique()
# Out:
# array(['Business', 'Economy', 'Economy Plus'], dtype=object)

# %%
df.nunique()
# Out:
# ID                                        129880
# Gender                                         2
# Age                                           75
# Customer Type                                  2
# Type of Travel                                 2
# Class                                          3
# Flight Distance                             3821
# Departure Delay                              466
# Arrival Delay                                472
# Departure and Arrival Time Convenience         6
# Ease of Online Booking                         6
# Check-in Service                               6
# Online Boarding                                6
# Gate Location                                  6
# On-board Service                               6
# Seat Comfort                                   6
# Leg Room Service                               6
# Cleanliness                                    6
# Food and Drink                                 6
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr(numeric_only=True)

# %%
import pandas as pd
df=pd.read_csv("/content/Bank_Churn.csv")

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
df.tail()
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 9995       0.00              2          1               0         96270.64
# 9996   57369.61              1          1               1        101699.77
# 9997       0.00              1          0               1         42085.58
# 9998   75075.31              2          1               0         92888.52
# 9999  130142.79              1          1               0         38190.78
#
#       Exited
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# ...

# %%
df.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure        Balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# ...

# %%
df.value_counts()
# Out:
# CustomerId  Surname   CreditScore  Geography  Gender  Age  Tenure  Balance    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 15815316    Kennedy   644          France     Male    50   9       76817.00   4              1          0               196371.13        1         1
# 15815295    John      662          France     Female  38   2       96479.81   1              1          0               120259.41        0         1
# 15815271    Ritchie   755          Germany    Male    43   6       165048.50  3              1          0               16929.41         1         1
# 15815259    Fang      835          France     Female  56   2       0.00       2              1          1               39820.13         0         1
# 15815236    Chiganu   574          Spain      Male    34   5       0.00       2              0          0               28269.86         0         1
# ...

# %%
df.head(10)
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
# 5    15574012       Chu          645     Spain    Male   44       8
# 6    15592531  Bartlett          822    France    Male   50       7
# 7    15656148    Obinna          376   Germany  Female   29       4
# 8    15792365        He          501    France    Male   44       4
# 9    15592389        H?          684    France    Male   27       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# ...

# %%
df.sample(5)
# Out:
#       CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 2300    15647266      Y?an          651     Spain  Female   45      10
# 8082    15774551        K?          772     Spain    Male   36       3
# 4307    15702499  Schnaars          770     Spain    Male   46       9
# 7857    15621457       Chu          850    France    Male   27       6
# 2687    15679148    Oliver          508    France    Male   44       3
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 2300  135923.16              1          1               0         18732.84
# 8082  112029.83              1          1               1        186948.35
# 4307  190678.02              1          1               1         14725.36
# 7857   96654.72              2          0               0        152740.16
# 2687  115451.05              2          0               0         67234.33
#
#       Exited
# 2300       0
# 8082       0
# 4307       0
# 7857       0
# 2687       0

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
df.dtypes
# Out:
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df["Gender"]
# Out:
# 0       Female
# 1       Female
# 2       Female
# 3       Female
# 4       Female
#          ...
# 9995      Male
# 9996      Male
# 9997    Female
# 9998      Male
# 9999    Female
# Name: Gender, Length: 10000, dtype: object

# %%
df[["Gender","Age","Tenure"]]
# Out:
#       Gender  Age  Tenure
# 0     Female   42       2
# 1     Female   41       1
# 2     Female   42       8
# 3     Female   39       1
# 4     Female   43       2
# ...      ...  ...     ...
# 9995    Male   39       5
# 9996    Male   35      10
# 9997  Female   36       7
# 9998    Male   42       3
# 9999  Female   28       4
#
# [10000 rows x 3 columns]

# %%
df.iloc[0]
# Out:
# CustomerId          15634602
# Surname             Hargrave
# CreditScore              619
# Geography             France
# Gender                Female
# Age                       42
# Tenure                     2
# Balance                  0.0
# NumOfProducts              1
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    101348.88
# Exited                     1
# Name: 0, dtype: object

# %%
df.iloc[0:10]
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
# 5    15574012       Chu          645     Spain    Male   44       8
# 6    15592531  Bartlett          822    France    Male   50       7
# 7    15656148    Obinna          376   Germany  Female   29       4
# 8    15792365        He          501    France    Male   44       4
# 9    15592389        H?          684    France    Male   27       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# ...

# %%
df.loc[0]
# Out:
# CustomerId          15634602
# Surname             Hargrave
# CreditScore              619
# Geography             France
# Gender                Female
# Age                       42
# Tenure                     2
# Balance                  0.0
# NumOfProducts              1
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    101348.88
# Exited                     1
# Name: 0, dtype: object

# %%
df.isnull()
# Out:
#       CustomerId  Surname  CreditScore  Geography  Gender    Age  Tenure  \
# 0          False    False        False      False   False  False   False
# 1          False    False        False      False   False  False   False
# 2          False    False        False      False   False  False   False
# 3          False    False        False      False   False  False   False
# 4          False    False        False      False   False  False   False
# ...          ...      ...          ...        ...     ...    ...     ...
# 9995       False    False        False      False   False  False   False
# 9996       False    False        False      False   False  False   False
# 9997       False    False        False      False   False  False   False
# 9998       False    False        False      False   False  False   False
# 9999       False    False        False      False   False  False   False
#
#       Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df.isnull().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.notnull()
# Out:
#       CustomerId  Surname  CreditScore  Geography  Gender   Age  Tenure  \
# 0           True     True         True       True    True  True    True
# 1           True     True         True       True    True  True    True
# 2           True     True         True       True    True  True    True
# 3           True     True         True       True    True  True    True
# 4           True     True         True       True    True  True    True
# ...          ...      ...          ...        ...     ...   ...     ...
# 9995        True     True         True       True    True  True    True
# 9996        True     True         True       True    True  True    True
# 9997        True     True         True       True    True  True    True
# 9998        True     True         True       True    True  True    True
# 9999        True     True         True       True    True  True    True
#
#       Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df.notnull().sum()
# Out:
# CustomerId         10000
# Surname            10000
# CreditScore        10000
# Geography          10000
# Gender             10000
# Age                10000
# Tenure             10000
# Balance            10000
# NumOfProducts      10000
# HasCrCard          10000
# IsActiveMember     10000
# EstimatedSalary    10000
# Exited             10000
# dtype: int64

# %%
df.dropna()
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df.fillna(0)
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df["Gender"].nunique()
# Out:
# 2

# %%
df["Age"].value_counts()
# Out:
# Age
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 84      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: count, Length: 70, dtype: int64

# %%
df.sort_values(by="Age")
# Out:
#       CustomerId          Surname  CreditScore Geography  Gender  Age  Tenure  \
# 1678    15569178        Kharlamov          570    France  Female   18       4
# 4556    15796231          Nwankwo          681    France  Female   18       1
# 9520    15673180      Onyekaozulu          727   Germany  Female   18       2
# 9526    15665521  Chiazagomekpele          642   Germany    Male   18       5
# 9572    15641688          Collier          644     Spain    Male   18       7
# ...          ...              ...          ...       ...     ...  ...     ...
# 3531    15653251           Hickey          408    France  Female   84       8
# 3033    15578006              Yao          787    France  Female   85      10
# 2458    15813303          Rearick          513     Spain    Male   88      10
# 6443    15764927           Rogova          753    France    Male   92       3
# 6759    15660878            T'ien          705    France    Male   92       1
#
# ...

# %%
df[df["Age"]>40]
# Out:
#       CustomerId      Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602     Hargrave          619    France  Female   42       2
# 1       15647311         Hill          608     Spain  Female   41       1
# 2       15619304         Onio          502    France  Female   42       8
# 4       15737888     Mitchell          850     Spain  Female   43       2
# 5       15574012          Chu          645     Spain    Male   44       8
# ...          ...          ...          ...       ...     ...  ...     ...
# 9981    15672754     Burbidge          498   Germany    Male   42       3
# 9982    15768163      Griffin          655   Germany  Female   46       7
# 9986    15581736     Bartlett          673   Germany    Male   47       1
# 9991    15769959  Ajuluchukwu          597    France  Female   53       4
# 9998    15682355    Sabbatini          772   Germany    Male   42       3
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df[df["Gender"]=="Male"]
# Out:
#       CustomerId      Surname  CreditScore Geography Gender  Age  Tenure  \
# 5       15574012          Chu          645     Spain   Male   44       8
# 6       15592531     Bartlett          822    France   Male   50       7
# 8       15792365           He          501    France   Male   44       4
# 9       15592389           H?          684    France   Male   27       2
# 10      15767821       Bearce          528    France   Male   31       6
# ...          ...          ...          ...       ...    ...  ...     ...
# 9992    15657105  Chukwualuka          726     Spain   Male   36       2
# 9993    15569266       Rahman          644    France   Male   28       7
# 9995    15606229     Obijiaku          771    France   Male   39       5
# 9996    15569892    Johnstone          516    France   Male   35      10
# 9998    15682355    Sabbatini          772   Germany   Male   42       3
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df["Tenure_after_2_years"]=df["Tenure"]+2

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited  Tenure_after_2_years
# 0       1                     4
# 1       0                     3
# ...

# %%
df.rename(columns={"Gendder":"Passenger Gender"})
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df.tail(2)
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 9998   75075.31              2          1               0         92888.52
# 9999  130142.79              1          1               0         38190.78
#
#       Exited  Tenure_after_2_years
# 9998       1                     5
# 9999       0                     6

# %%
df.drop("Tenure_after_2_years",axis=1)
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
left=df[["CustomerId","Gender"]]
right=df[["CustomerId","Age"]]
pd.merge(left,right,on="CustomerId")
# Out:
#       CustomerId  Gender  Age
# 0       15634602  Female   42
# 1       15647311  Female   41
# 2       15619304  Female   42
# 3       15701354  Female   39
# 4       15737888  Female   43
# ...          ...     ...  ...
# 9995    15606229    Male   39
# 9996    15569892    Male   35
# 9997    15584532  Female   36
# 9998    15682355    Male   42
# 9999    15628319  Female   28
#
# [10000 rows x 3 columns]

# %%
df["Age"].mean()
# Out:
# np.float64(38.9218)

# %%
df["Age"].max()
# Out:
# 92

# %%
df["Tenure"].sum()
# Out:
# np.int64(50128)

# %%
df["CustomerId"].min()
# Out:
# 15565701

# %%
df["Tenure"].median()
# Out:
# 5.0

# %%
df["Age"].count()
# Out:
# np.int64(10000)

# %%
df["Tenure"].std()
# Out:
# 2.892174377049708

# %%
#count missing values
missing_values=df.isnull().sum()
print(missing_values)
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# CustomerId         0.0
# Surname            0.0
# CreditScore        0.0
# Geography          0.0
# Gender             0.0
# Age                0.0
# Tenure             0.0
# Balance            0.0
# NumOfProducts      0.0
# HasCrCard          0.0
# IsActiveMember     0.0
# EstimatedSalary    0.0
# Exited             0.0
# dtype: float64

# %%
pd.DataFrame({"Missing Count": df.isnull().sum(), "Missing Percentage": (df.isnull().sum()/len(df))*100})
# Out:
#                  Missing Count  Missing Percentage
# CustomerId                   0                 0.0
# Surname                      0                 0.0
# CreditScore                  0                 0.0
# Geography                    0                 0.0
# Gender                       0                 0.0
# Age                          0                 0.0
# Tenure                       0                 0.0
# Balance                      0                 0.0
# NumOfProducts                0                 0.0
# HasCrCard                    0                 0.0
# IsActiveMember               0                 0.0
# EstimatedSalary              0                 0.0
# Exited                       0                 0.0
